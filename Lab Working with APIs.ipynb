# %%
import requests

# %%
url = 'https://api.coincap.io/v2/assets'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
type(response)
# Out:
# requests.models.Response

# %%
response.content
# Out:
# b'{"data":[{"id":"bitcoin","rank":"1","symbol":"BTC","name":"Bitcoin","supply":"19719981.0000000000000000","maxSupply":"21000000.0000000000000000","marketCapUsd":"1132962328064.2417060666155372","volumeUsd24Hr":"11502137207.7641224587063472","priceUsd":"57452.5060680454867612","changePercent24Hr":"-0.0491989559031050","vwap24Hr":"58109.9663121234943209","explorer":"https://blockchain.info/"},{"id":"ethereum","rank":"2","symbol":"ETH","name":"Ethereum","supply":"120209171.4182295800000000","maxSupply":null,"marketCapUsd":"374066128859.0266506949163946","volumeUsd24Hr":"7822894128.5351843097810374","priceUsd":"3111.7935881745871558","changePercent24Hr":"0.0854709671405306","vwap24Hr":"3131.2178350280849755","explorer":"https://etherscan.io/"},{"id":"tether","rank":"3","symbol":"USDT","name":"Tether","supply":"112259808785.1427800000000000","maxSupply":null,"marketCapUsd":"112346603698.1404967738342791","volumeUsd24Hr":"14872132478.8709119660076800","priceUsd":"1.0007731610621557","chan
# ...

# %%
info =response.json()
info
# Out:
# {'data': [{'id': 'bitcoin',
#    'rank': '1',
#    'symbol': 'BTC',
#    'name': 'Bitcoin',
#    'supply': '19719981.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '1132962328064.2417060666155372',
#    'volumeUsd24Hr': '11502137207.7641224587063472',
#    'priceUsd': '57452.5060680454867612',
#    'changePercent24Hr': '-0.0491989559031050',
#    'vwap24Hr': '58109.9663121234943209',
#    'explorer': 'https://blockchain.info/'},
#   {'id': 'ethereum',
#    'rank': '2',
#    'symbol': 'ETH',
#    'name': 'Ethereum',
#    'supply': '120209171.4182295800000000',
#    'maxSupply': None,
#    'marketCapUsd': '374066128859.0266506949163946',
#    'volumeUsd24Hr': '7822894128.5351843097810374',
#    'priceUsd': '3111.7935881745871558',
#    'changePercent24Hr': '0.0854709671405306',
#    'vwap24Hr': '3131.2178350280849755',
#    'explorer': 'https://etherscan.io/'},
#   {'id': 'tether',
#    'rank': '3',
#    'symbol': 'USDT',
#    'name': 'Tether',
# ...

# %%
info
# Out:
# {'data': [{'id': 'bitcoin',
#    'rank': '1',
#    'symbol': 'BTC',
#    'name': 'Bitcoin',
#    'supply': '19719981.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '1132962328064.2417060666155372',
#    'volumeUsd24Hr': '11502137207.7641224587063472',
#    'priceUsd': '57452.5060680454867612',
#    'changePercent24Hr': '-0.0491989559031050',
#    'vwap24Hr': '58109.9663121234943209',
#    'explorer': 'https://blockchain.info/'},
#   {'id': 'ethereum',
#    'rank': '2',
#    'symbol': 'ETH',
#    'name': 'Ethereum',
#    'supply': '120209171.4182295800000000',
#    'maxSupply': None,
#    'marketCapUsd': '374066128859.0266506949163946',
#    'volumeUsd24Hr': '7822894128.5351843097810374',
#    'priceUsd': '3111.7935881745871558',
#    'changePercent24Hr': '0.0854709671405306',
#    'vwap24Hr': '3131.2178350280849755',
#    'explorer': 'https://etherscan.io/'},
#   {'id': 'tether',
#    'rank': '3',
#    'symbol': 'USDT',
#    'name': 'Tether',
# ...

# %%
import pandas as pd
pd.DataFrame(info['data'])
# Out:
#               id rank symbol      name                         supply  \
# 0        bitcoin    1    BTC   Bitcoin      19719981.0000000000000000
# 1       ethereum    2    ETH  Ethereum     120209171.4182295800000000
# 2         tether    3   USDT    Tether  112259808785.1427800000000000
# 3   binance-coin    4    BNB       BNB     166801148.0000000000000000
# 4         solana    5    SOL    Solana     463960292.5906939500000000
# ..           ...  ...    ...       ...                            ...
# 95          dash   96   DASH      Dash      11874253.8800896800000000
# 96      illuvium   97    ILV  Illuvium       4471878.2080871400000000
# 97          celo   98   CELO      Celo     542396781.0000000000000000
# 98          just   99    JST      JUST    9900000000.0000000000000000
# 99          aelf  100    ELF      aelf     731609229.9091900000000000
#
#                       maxSupply                    marketCapUsd  \
# ...
